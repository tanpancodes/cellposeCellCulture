# %%
import numpy as np
from cellpose import plot, utils, io
import matplotlib.pyplot as plt
from cellpose import models, io, utils
from cellpose.io import imread
import os
import glob
# Out:
# ['1-1-red_seg.npy', '1-2-red_seg.npy', '10-1-red_seg.npy', '10-2-red_seg.npy', '11-1-red_seg.npy', '11-2-red_seg.npy', '12-1-red_seg.npy', '12-2-red_seg.npy', '13-1-red_seg.npy', '13-2-red_seg.npy', '14-1-red_seg.npy', '14-2-red_seg.npy', '15-1-red_seg.npy', '15-2-red_seg.npy', '16-1-red_seg.npy', '16-2-red_seg.npy', '17-1-red_seg.npy', '17-2-red_seg.npy', '18-1-red_seg.npy', '18-2-red_seg.npy', '19-1-red_seg.npy', '19-2-red_seg.npy', '2-1-red_seg.npy', '2-2-red_seg.npy', '20-1-red_seg.npy', '20-2-red_seg.npy', '21-1-red_seg.npy', '21-2-red_seg.npy', '22-1-red_seg.npy', '22-2-red_seg.npy', '23-1-red_seg.npy', '23-2-red_seg.npy', '24-1-red_seg.npy', '24-2-red_seg.npy', '3-1-red_seg.npy', '3-2-red_seg.npy', '4-1-red_seg.npy', '4-2-red_seg.npy', '5-1-red_seg.npy', '5-2-red_seg.npy', '6-1-red_seg.npy', '6-2-red_seg.npy', '7-1-red_seg.npy', '7-2-red_seg.npy', '8-1-red_seg.npy', '8-2-red_seg.npy', '9-1-red_seg.npy', '9-2-red_seg.npy']
# 1-1-red_seg.npy
# 327
# 1-2-red_seg.npy
# 400
# 10-1-red_seg.npy
# 127
# 10-2-red_seg.npy
# 95
# 11-1-red_seg.npy
# 206
# 11-2-red_seg.npy
# 218
# 12-1-red_seg.npy
# 176
# 12-2-red_seg.npy
# 150
# 13-1-red_seg.npy
# 203
# 13-2-red_seg.npy
# 269
# 14-1-red_seg.npy
# 296
# 14-2-red_seg.npy
# 392
# 15-1-red_seg.npy
# 97
# 15-2-red_seg.npy
# 124
# 16-1-red_seg.npy
# 118
# 16-2-red_seg.npy
# 119
# 17-1-red_seg.npy
# 203
# 17-2-red_seg.npy
# 221
# 18-1-red_seg.npy
# 183
# 18-2-red_seg.npy
# 182
# 19-1-red_seg.npy
# 98
# 19-2-red_seg.npy
# 129
# 2-1-red_seg.npy
# 483
# 2-2-red_seg.npy
# 402
# 20-1-red_seg.npy
# 103
# 20-2-red_seg.npy
# 97
# 21-1-red_seg.npy
# 751
# 21-2-red_seg.npy
# 754
# 22-1-red_seg.npy
# 718
# 22-2-red_seg.npy
# 789
# 23-1-red_seg.npy
# 1
# 23-2-red_seg.npy
# 6
# 24-1-red_seg.npy
# 3
# 24-2-red_seg.npy
# 1
# 3-1-red_seg.npy
# 626
# 3-2-red_seg.npy
# 628
# 4-1-red_seg.npy
# 634
# 4-2-red_seg.npy
# 708
# 5-1-red_seg.npy
# 503
# 5-2-red_seg.npy
# 427
# 6-1-red_seg.npy
# 572
# 6-2-red_seg.npy
# 578
# 7-1-red_seg.npy
# 100
# 7-2-red_seg.npy
# 101
# 8-1-red_seg.npy
# 111
# 8-2-red_seg.npy
# 129
# 9-1-red_seg.npy
# 79
# 9-2-red_seg.npy
# 89

# %%
#put pathway to your images below:
filepath = r"C:\Users\hitan\IntrRes\im24.02.29"

#changeDirectory to filepath specified
os.chdir(filepath)
files = os.listdir()
#print(files)
#print(len(files)) #the output number should match the number of images in your fold

numberofLoops = 0

print(glob.glob('*.np[yz]'))

numpy_vars = {}
for np_name in glob.glob('*.np[yz]'):
    numpy_vars[np_name] = np.load(np_name, allow_pickle=True).item()
    dat = numpy_vars[np_name]
    outlines = utils.outlines_list(dat['masks'])

    count =0
    for o in outlines:
        #plt.plot(o[:,0], o[:,1], color='r')
        count += 1
    print(np_name)
    print(count)
